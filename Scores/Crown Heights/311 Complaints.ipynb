# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import datetime

# %%
complaints = pd.read_csv(r'/Users/mansi/Downloads/311_Service_Requests_from_2010_to_Present.csv')
# Out:
# /var/folders/2z/1nrgnypj77l8fzt2ybvcrf580000gp/T/ipykernel_15515/255520202.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv(r'/Users/mansi/Downloads/311_Service_Requests_from_2010_to_Present.csv')

# %%
# Delete columns that are all NAN
complaints.dropna(axis=1, how='all', inplace=True)

# %%
complaints
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         45750827  03/03/2020 09:34:59 PM  03/04/2020 12:31:20 AM   NYPD
# 1         45751284  03/04/2020 08:53:05 PM  03/05/2020 01:33:57 AM   NYPD
# 2         45830501  03/10/2020 03:10:44 AM  03/10/2020 07:22:32 AM   NYPD
# 3         45767913  03/06/2020 11:34:43 PM  03/09/2020 12:37:19 AM   NYPD
# 4         45778796  03/14/2020 06:13:43 PM  03/14/2020 11:15:32 PM   NYPD
# ...            ...                     ...                     ...    ...
# 623593    47265257  08/16/2020 12:12:15 AM  08/16/2020 03:39:13 AM   NYPD
# 623594    47269971  08/17/2020 06:06:04 AM  08/17/2020 09:11:09 AM   NYPD
# 623595    43754667  09/09/2019 11:50:00 AM  09/30/2019 09:25:00 AM    DEP
# 623596    43772811  09/11/2019 06:00:00 PM  09/27/2019 02:00:00 PM    DEP
# 623597    46113165  05/02/2020 12:17:00 AM  05/05/2020 08:08:00 PM    DEP
#
#                                    Agency Name           Complaint Type  \
# ...

# %%
complaints['Descriptor'].value_counts()
# Out:
# Loud Music/Party                                  364838
# Banging/Pounding                                   88657
# Loud Talking                                       51297
# Car/Truck Music                                    35201
# Construction Before/After Hours (NM1)              23448
# Engine Idling                                      10702
# Car/Truck Horn                                      9843
# Construction Equipment (NC1)                        8703
# Barking Dog (NR5)                                   6937
# Loud Television                                     6079
# Alarms (NR3)                                        4175
# air condition/ventilation equipment (NV1)           3939
# Jack Hammering (NC2)                                2910
# Other                                               2307
# Ice Cream Truck (NR4)                               1449
# NYPD                                                 749
# ...

# %%
complaints['Complaint Type'].value_counts()
# Out:
# Noise - Residential         317066
# Noise - Street/Sidewalk     132015
# Noise - Commercial           58811
# Noise                        53675
# Noise - Vehicle              51301
# Noise - Park                  6233
# Noise - Helicopter            3235
# Noise - House of Worship      1193
# Collection Truck Noise          69
# Name: Complaint Type, dtype: int64

# %%
complaints['Descriptor'] = complaints['Descriptor'].str.replace('Noise: ', '')

# %%
complaints['Descriptor'] = complaints['Descriptor'].str.replace('Noise, ', '')
